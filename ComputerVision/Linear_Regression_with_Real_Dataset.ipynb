# %% [markdown]
# <a href="https://colab.research.google.com/github/dorisratego/TensorFlowML-AI/blob/main/Linear_Regression_with_Real_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Run on TensorFlow 2.x
# %tensorflow_version 2.x

# %%
#@title Import relevant modules
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
# Import the dataset.
training_df = pd.read_csv(filepath_or_buffer="https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")

# Scale the label.
training_df["median_house_value"] /= 1000.0

# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0     -114.3      34.2  ...            1.5                66.9
# 1     -114.5      34.4  ...            1.8                80.1
# 2     -114.6      33.7  ...            1.7                85.7
# 3     -114.6      33.6  ...            3.2                73.4
# 4     -114.6      33.6  ...            1.9                65.5
#
# [5 rows x 9 columns]

# %%
# Get statistics on the dataset.
training_df.describe()
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# count    17000.0   17000.0  ...        17000.0             17000.0
# mean      -119.6      35.6  ...            3.9               207.3
# std          2.0       2.1  ...            1.9               116.0
# min       -124.3      32.5  ...            0.5                15.0
# 25%       -121.8      33.9  ...            2.6               119.4
# 50%       -118.5      34.2  ...            3.5               180.4
# 75%       -118.0      37.7  ...            4.8               265.0
# max       -114.3      42.0  ...           15.0               500.0
#
# [8 rows x 9 columns]

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Describe the topography of the model.
  # The topography of a simple linear regression model
  # is a single node in a single layer.
  model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model        


def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs. 
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch. 
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

print("Defined the create_model and traing_model functions.")
# Out:
# Defined the create_model and traing_model functions.

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 200 random points of the dataset.
  random_examples = training_df.sample(n=200)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = 10000
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()


def plot_the_loss_curve(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.05
epochs = 18
batch_size = 3

# Specify the feature and the label.
my_feature = "population"  # the total number of rooms on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on total_rooms.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# Epoch 1/18
# 5667/5667 [==============================] - 5s 863us/step - loss: 137531.0463 - root_mean_squared_error: 316.0331
# Epoch 2/18
# 5667/5667 [==============================] - 5s 863us/step - loss: 20404.0285 - root_mean_squared_error: 142.8043
# Epoch 3/18
# 5667/5667 [==============================] - 5s 853us/step - loss: 19017.9136 - root_mean_squared_error: 137.8383
# Epoch 4/18
# 5667/5667 [==============================] - 5s 855us/step - loss: 18504.6131 - root_mean_squared_error: 136.0062
# Epoch 5/18
# 5667/5667 [==============================] - 5s 873us/step - loss: 19677.4702 - root_mean_squared_error: 140.1642
# Epoch 6/18
# 5667/5667 [==============================] - 5s 853us/step - loss: 17884.7536 - root_mean_squared_error: 133.7206
# Epoch 7/18
# 5667/5667 [==============================] - 5s 851us/step - loss: 17668.6510 - root_mean_squared_error: 132.9046
# Epoch 8/18
# 5667/5667 [==============================] - 5s 849us/step - loss: 18100.7067 - root_mean_squared_error: 134.5323
# Epoch 9/18
# 5667/5667 [==============================] - 5s 846us/step - loss: 18146.1632 - root_mean_squared_error: 134.6913
# Epoch 10/18
# 5667/5667 [==============================] - 5s 868us/step - loss: 18112.5900 - root_mean_squared_error: 134.5616
# Epoch 11/18
# 5667/5667 [==============================] - 5s 855us/step - loss: 18042.3256 - root_mean_squared_error: 134.3124
# Epoch 12/18
# 5667/5667 [==============================] - 5s 852us/step - loss: 18075.6113 - root_mean_squared_error: 134.4212
# Epoch 13/18
# 5667/5667 [==============================] - 5s 862us/step - loss: 17839.7597 - root_mean_squared_error: 133.5083
# Epoch 14/18
# 5667/5667 [==============================] - 5s 862us/step - loss: 18320.8214 - root_mean_squared_error: 135.3343
# Epoch 15/18
# 5667/5667 [==============================] - 5s 864us/step - loss: 18161.2060 - root_mean_squared_error: 134.7104
# Epoch 16/18
# 5667/5667 [==============================] - 5s 853us/step - loss: 18769.6308 - root_mean_squared_error: 136.9427
# Epoch 17/18
# 5667/5667 [==============================] - 5s 861us/step - loss: 18056.0261 - root_mean_squared_error: 134.3533
# Epoch 18/18
# 5667/5667 [==============================] - 5s 866us/step - loss: 17988.5218 - root_mean_squared_error: 134.1047
#
# The learned weight for your model is -0.0131
# The learned bias for your model is 209.6796
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
def predict_house_values(n, feature, label):
  """Predict house values based on a feature."""

  batch = training_df[feature][10000:10000 + n]
  predicted_values = my_model.predict_on_batch(x=batch)

  print("feature   label          predicted")
  print("  value   value          value")
  print("          in thousand$   in thousand$")
  print("--------------------------------------")
  for i in range(n):
    print ("%5.0f %6.0f %15.0f" % (training_df[feature][10000 + i],
                                   training_df[label][10000 + i],
                                   predicted_values[i][0] ))

# %%
predict_house_values(10, my_feature, my_label)
# Out:
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#  1960     53             204
#  3400     92             259
#  3677     69             269
#  2202     62             213
#  2403     80             221
#  5652    295             344
#  3318    500             256
#  2552    342             227
#  1364    118             182
#  3468    128             261

# %%
# Define a synthetic feature named rooms_per_person
training_df["rooms_per_person"] = training_df["total_rooms"]/ training_df["population"] # write your code here.

# Don't change the next line.
my_feature = "rooms_per_person"

# Assign values to these three hyperparameters.
learning_rate = 0.06
epochs = 24
batch_size = 30

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df,
                                         my_feature, my_label,
                                         epochs, batch_size)

plot_the_loss_curve(epochs, rmse)
predict_house_values(15, my_feature, my_label)
# Out:
# Epoch 1/24
# 567/567 [==============================] - 1s 870us/step - loss: 45309.1072 - root_mean_squared_error: 212.5527
# Epoch 2/24
# 567/567 [==============================] - 0s 860us/step - loss: 20832.1832 - root_mean_squared_error: 144.2581
# Epoch 3/24
# 567/567 [==============================] - 1s 894us/step - loss: 15769.2812 - root_mean_squared_error: 125.4331
# Epoch 4/24
# 567/567 [==============================] - 1s 882us/step - loss: 14453.7563 - root_mean_squared_error: 120.1253
# Epoch 5/24
# 567/567 [==============================] - 1s 942us/step - loss: 15543.2194 - root_mean_squared_error: 124.4741
# Epoch 6/24
# 567/567 [==============================] - 0s 872us/step - loss: 14690.7161 - root_mean_squared_error: 121.1613
# Epoch 7/24
# 567/567 [==============================] - 1s 921us/step - loss: 14401.5953 - root_mean_squared_error: 119.9136
# Epoch 8/24
# 567/567 [==============================] - 1s 953us/step - loss: 13938.2253 - root_mean_squared_error: 118.0295
# Epoch 9/24
# 567/567 [==============================] - 1s 887us/step - loss: 13944.9301 - root_mean_squared_error: 118.0521
# Epoch 10/24
# 567/567 [==============================] - 0s 860us/step - loss: 14744.5188 - root_mean_squared_error: 121.2614
# Epoch 11/24
# 567/567 [==============================] - 1s 923us/step - loss: 14624.4565 - root_mean_squared_error: 120.7197
# Epoch 12/24
# 567/567 [==============================] - 1s 908us/step - loss: 13745.8963 - root_mean_squared_error: 117.2009
# Epoch 13/24
# 567/567 [==============================] - 1s 918us/step - loss: 15162.7579 - root_mean_squared_error: 122.8195
# Epoch 14/24
# 567/567 [==============================] - 1s 884us/step - loss: 13640.1545 - root_mean_squared_error: 116.7786
# Epoch 15/24
# 567/567 [==============================] - 1s 906us/step - loss: 12775.9007 - root_mean_squared_error: 113.0038
# Epoch 16/24
# 567/567 [==============================] - 1s 905us/step - loss: 12594.3676 - root_mean_squared_error: 112.1851
# Epoch 17/24
# 567/567 [==============================] - 1s 926us/step - loss: 13034.4773 - root_mean_squared_error: 114.1084
# Epoch 18/24
# 567/567 [==============================] - 1s 887us/step - loss: 14209.5516 - root_mean_squared_error: 119.1328
# Epoch 19/24
# 567/567 [==============================] - 1s 936us/step - loss: 14039.3515 - root_mean_squared_error: 118.4503
# Epoch 20/24
# 567/567 [==============================] - 1s 916us/step - loss: 13764.7655 - root_mean_squared_error: 117.2348
# Epoch 21/24
# 567/567 [==============================] - 1s 935us/step - loss: 13251.4413 - root_mean_squared_error: 115.0558
# Epoch 22/24
# 567/567 [==============================] - 1s 888us/step - loss: 13477.7142 - root_mean_squared_error: 116.0672
# Epoch 23/24
# 567/567 [==============================] - 1s 910us/step - loss: 12798.8013 - root_mean_squared_error: 113.1014
# Epoch 24/24
# 567/567 [==============================] - 1s 946us/step - loss: 12931.8735 - root_mean_squared_error: 113.7107
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#     2     53             189
#     2     92             200
#     2     69             195
#     2     62             211
#     1     80             186
#     2    295             225
#     2    500             210
#     2    342             223
#     4    118             287
#     2    128             214
#     2    187             224
#     3     80             234
#     2    112             224
#     2     95             219
#     2     69             210

# %%
# Generate a correlation matrix.
training_df.corr()
# Out:
#                     longitude  latitude  ...  median_house_value  rooms_per_person
# longitude                 1.0      -0.9  ...                -0.0              -0.1
# latitude                 -0.9       1.0  ...                -0.1               0.1
# housing_median_age       -0.1       0.0  ...                 0.1              -0.1
# total_rooms               0.0      -0.0  ...                 0.1               0.1
# total_bedrooms            0.1      -0.1  ...                 0.0               0.0
# population                0.1      -0.1  ...                -0.0              -0.1
# households                0.1      -0.1  ...                 0.1              -0.0
# median_income            -0.0      -0.1  ...                 0.7               0.2
# median_house_value       -0.0      -0.1  ...                 1.0               0.2
# rooms_per_person         -0.1       0.1  ...                 0.2               1.0
#
# [10 rows x 10 columns]
